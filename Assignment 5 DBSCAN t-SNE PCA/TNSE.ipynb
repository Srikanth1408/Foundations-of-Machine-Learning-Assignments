# %%
import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np
import sklearn
import seaborn as sns
from scipy import stats
# %matplotlib inline

# %%
# Imported Dataset
from sklearn.datasets import load_digits        
digits = load_digits()

# %%
digits.data
# Out:
# array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#        ...,
#        [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#        [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#        [ 0.,  0., 10., ..., 12.,  1.,  0.]])

# %%
plt.gray()
plt.matshow(digits.images[17])
plt.show()

# %%
X = digits.data
y = digits.target

# %%
# Implemented with 1000 iterations
from sklearn.manifold import TSNE
tsne = TSNE(perplexity= 30, n_iter=1000, random_state=0)

# %%
tsne_obj= tsne.fit_transform(X)

# %%
tsne_obj
# Out:
# array([[ 69.52948  ,   6.5252523],
#        [  3.9794986, -14.218749 ],
#        [  4.5955944,  13.874503 ],
#        ...,
#        [ -4.6140466,   6.310683 ],
#        [-28.619677 ,  26.985363 ],
#        [ -7.3243384,  12.500263 ]], dtype=float32)

# %%
# Created a Dataframe from available data
tsne_df = pd.DataFrame({'X':tsne_obj[:,0],
                        'Y':tsne_obj[:,1],
                        'digit':y})
tsne_df.head(10)
# Out:
#            X          Y  digit
# 0  69.529480   6.525252      0
# 1   3.979499 -14.218749      1
# 2   4.595594  13.874503      2
# 3 -14.904782  41.026440      3
# 4   9.150412 -46.465809      4
# 5 -26.213343  33.183346      5
# 6  30.307407 -14.437242      6
# 7 -38.601791 -35.249996      7
# 8  -8.558921  13.377447      8
# 9 -27.601561  26.600737      9

# %%
sns.scatterplot(x="X", y="Y",
              hue="digit",
              palette=['purple','red','orange','brown','blue',
                       'dodgerblue','green','lightgreen','darkcyan', 'black'],
              legend='full',
              data=tsne_df);

# %%
# Implemented with 500 iterations
tsne3 = TSNE(perplexity= 30, n_iter=500, random_state=0)

# %%
tsne3_obj= tsne3.fit_transform(X)

# %%
tsne3_df = pd.DataFrame({'X':tsne3_obj[:,0],
                        'Y':tsne3_obj[:,1],
                        'digit':y})
tsne3_df.head()
# Out:
#            X          Y  digit
# 0  47.627941   5.014102      0
# 1   3.244353 -11.491253      1
# 2   4.402637  11.381968      2
# 3 -11.633854  32.748940      3
# 4   8.307107 -35.422646      4

# %%
sns.scatterplot(x="X", y="Y",
              hue="digit",
              palette=['purple','red','orange','brown','blue',
                       'dodgerblue','green','lightgreen','darkcyan', 'black'],
              legend='full',
              data=tsne1_df);

# %%
# Implemented with 2000 iterations
tsne1 = TSNE(perplexity= 30, n_iter=2000, random_state=0)

# %%
tsne1_obj= tsne1.fit_transform(X)

# %%
tsne1_df = pd.DataFrame({'X':tsne1_obj[:,0],
                        'Y':tsne1_obj[:,1],
                        'digit':y})
tsne1_df.head()
# Out:
#            X          Y  digit
# 0  89.968842   7.733066      0
# 1   5.207407 -16.001245      1
# 2   5.587610  15.588107      2
# 3 -17.430723  46.879059      3
# 4  10.293307 -54.308163      4

# %%
sns.scatterplot(x="X", y="Y",
              hue="digit",
              palette=['purple','red','orange','brown','blue',
                       'dodgerblue','green','lightgreen','darkcyan', 'black'],
              legend='full',
              data=tsne1_df);

# %%
# Implemented with 250 iterations
tsne2 = TSNE(perplexity= 30, n_iter=250, random_state=0)

# %%
tsne2_obj= tsne2.fit_transform(X)

# %%
tsne2_df = pd.DataFrame({'X':tsne2_obj[:,0],
                        'Y':tsne2_obj[:,1],
                        'digit':y})
tsne2_df.head()
# Out:
#           X         Y  digit
# 0  4.464197 -0.123148      0
# 1 -0.196225 -0.397904      1
# 2 -0.246978  0.184286      2
# 3 -1.187031  1.329658      3
# 4  0.078261 -2.209544      4

# %%
sns.scatterplot(x="X", y="Y",
              hue="digit",
              palette=['purple','red','orange','brown','blue',
                       'dodgerblue','green','lightgreen','darkcyan', 'black'],
              legend='full',
              data=tsne2_df);
